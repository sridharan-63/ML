# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import linearRegression
salesdata={"week":[1,2,3,4,5],
# Out:
#   Cell In[1], line 4
#     salesdata={"week":[1,2,3,4,5],
#                                   ^
# SyntaxError: incomplete input

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import linearRegression
salesdata={"week":[1,2,3,4,5],
               "sales":[1.2,1.8,2.6,3.2,3.8]}
df=pd.DataFrame(salesdata,columns=["wee","sales"]
                plt.scatter(df["week"],dp["sales"],color='green')
                plt.title("Regression amoung week and sales")
                plt.xlabel('x-axis-week')
                plt.ylabel('y-axis-sales')
week=df["week"].values.reshape(1,-1)
sales=d["sales"].value.reshape(1,-1)
x=df[["week"]]
y=df["sales"]
regr=linear_model.linearRegression()
regr.fit(x,y)
print("Intercept:\n",regr.intercept)
print("Coefficents:\n",regr.coeff_)
print("\n The Regression equation 's',regr.coef_,'*x+",regr intercept_)
pred=regr.predict(x)
plt.plot(x.pred)
print("\n Adjusted R squared for regression model:",regr.score(x,y))
# Out:
#   Cell In[2], line 6
#     df=pd.DataFrame(salesdata,columns=["wee","sales"]
#                    ^
# SyntaxError: '(' was never closed

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
data = {
    "Week": [1, 2, 3, 4, 5],
    "Sales": [1.2, 1.8, 2.6, 3.2, 3.8]}
df = pd.DataFrame(data)
X = df[["Week"]]
Y = df["Sales"]
model = LinearRegression()
model.fit(X, Y)
Y_pred = model.predict(X)
print("Intercept =", model.intercept_)
print("Coefficient =", model.coef_[0])
print("Regression Equation:")
print("Y =", model.coef_[0], "* X +", model.intercept_)
plt.scatter(df["Week"], df["Sales"], color="blue", label="Actual Data")
plt.plot(df["Week"], Y_pred, color="red", label="Regression Line")
plt.title("Linear Regression")
plt.xlabel("Week")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()
print("R² Score =", model.score(X, Y))
# Out:
# Intercept = 0.5400000000000005
# Coefficient = 0.66
# Regression Equation:
# Y = 0.66 * X + 0.5400000000000005
# R² Score = 0.9972527472527473

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
